# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Predicting-Heterogenous-Human-Activity-using-Smartphone-Senor-Data!" data-toc-modified-id="Predicting-Heterogenous-Human-Activity-using-Smartphone-Senor-Data!-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Predicting Heterogenous Human Activity using Smartphone Senor Data!</a></span><ul class="toc-item"><li><span><a href="#Abstract" data-toc-modified-id="Abstract-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Abstract</a></span></li><li><span><a href="#Data-Description" data-toc-modified-id="Data-Description-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Description</a></span></li><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Motivation" data-toc-modified-id="Motivation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Motivation</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#Data-Ingestion" data-toc-modified-id="Data-Ingestion-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Data Ingestion</a></span><ul class="toc-item"><li><span><a href="#Consolidating-Train-Data" data-toc-modified-id="Consolidating-Train-Data-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Consolidating Train Data</a></span></li><li><span><a href="#Consolidating-Test-Data" data-toc-modified-id="Consolidating-Test-Data-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Consolidating Test Data</a></span></li><li><span><a href="#Consolidating-both-Test-and-Train-Data" data-toc-modified-id="Consolidating-both-Test-and-Train-Data-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Consolidating both Test and Train Data</a></span></li><li><span><a href="#Data-Ingestion-Observations" data-toc-modified-id="Data-Ingestion-Observations-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Data Ingestion Observations</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Checking-Dataframe-Properties" data-toc-modified-id="Checking-Dataframe-Properties-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Checking Dataframe Properties</a></span></li><li><span><a href="#Checking-for-redundant-rows" data-toc-modified-id="Checking-for-redundant-rows-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Checking for redundant rows</a></span></li><li><span><a href="#Checking-for-Null-Values" data-toc-modified-id="Checking-for-Null-Values-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>Checking for Null Values</a></span></li></ul></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Creating-Pipeline" data-toc-modified-id="Creating-Pipeline-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>Creating Pipeline</a></span></li><li><span><a href="#Splitting-Data" data-toc-modified-id="Splitting-Data-1.9.3"><span class="toc-item-num">1.9.3&nbsp;&nbsp;</span>Splitting Data</a></span></li><li><span><a href="#Modelling-:-Logistic-Regression-using-PCA" data-toc-modified-id="Modelling-:-Logistic-Regression-using-PCA-1.9.4"><span class="toc-item-num">1.9.4&nbsp;&nbsp;</span>Modelling : Logistic Regression using PCA</a></span></li><li><span><a href="#Modelling-:-Logistic-Regression-using-Kernal-PCA" data-toc-modified-id="Modelling-:-Logistic-Regression-using-Kernal-PCA-1.9.5"><span class="toc-item-num">1.9.5&nbsp;&nbsp;</span>Modelling : Logistic Regression using Kernal PCA</a></span></li><li><span><a href="#Modelling-:-Decision-Tree" data-toc-modified-id="Modelling-:-Decision-Tree-1.9.6"><span class="toc-item-num">1.9.6&nbsp;&nbsp;</span>Modelling : Decision Tree</a></span></li><li><span><a href="#Modelling-:-SVM-Tree" data-toc-modified-id="Modelling-:-SVM-Tree-1.9.7"><span class="toc-item-num">1.9.7&nbsp;&nbsp;</span>Modelling : SVM Tree</a></span></li><li><span><a href="#Modelling-:K-Nearest-Neighbours-(KNN)" data-toc-modified-id="Modelling-:K-Nearest-Neighbours-(KNN)-1.9.8"><span class="toc-item-num">1.9.8&nbsp;&nbsp;</span>Modelling :K Nearest Neighbours (KNN)</a></span></li></ul></li><li><span><a href="#Feature-Importance-with-Random-Forests" data-toc-modified-id="Feature-Importance-with-Random-Forests-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Feature Importance with Random Forests</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Results</a></span></li><li><span><a href="#Challenges" data-toc-modified-id="Challenges-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Challenges</a></span></li><li><span><a href="#Next-Steps" data-toc-modified-id="Next-Steps-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Next Steps</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Predicting Heterogenous Human Activity using Smartphone Senor Data!
#
# **Project by** - Sushrutha Dhummi Thrilochana ( MM73053 )
#
# **Under Guidance** - Prof. Christopher McGraw

# %% [markdown]
# ## Abstract
#
# Human Activity Recognition database built from the recordings of 30 subjects performing activities of daily living (ADL) while carrying a waist-mounted smartphone with embedded inertial sensors.

# %% [markdown]
#
#    ##  Data Description

# %% [markdown]
# The features selected for this database come from the accelerometer and gyroscope 3-axial raw signals tAcc-XYZ and tGyro-XYZ. These time domain signals (prefix 't' to denote time) were captured at a constant rate of 50 Hz.  Similarly, the acceleration signal was then separated into body and gravity acceleration signals (tBodyAcc-XYZ and tGravityAcc-XYZ) .
# Subsequently, the body linear acceleration and angular velocity were derived in time to obtain Jerk signals (tBodyAccJerk-XYZ and tBodyGyroJerk-XYZ). Also the magnitude of these three-dimensional signals were calculated using the Euclidean norm (tBodyAccMag, tGravityAccMag, tBodyAccJerkMag, tBodyGyroMag, tBodyGyroJerkMag).
# These signals were used to estimate variables of the feature vector for each pattern:
# '-XYZ' is used to denote 3-axial signals in the X, Y and Z directions.
#
# - tBodyAcc-XYZ
# - tGravityAcc-XYZ
# - tBodyAccJerk-XYZ
# - tBodyGyro-XYZ
# - tBodyGyroJerk-XYZ
# - tBodyAccMag
# - tGravityAccMag
# - tBodyAccJerkMag
# - tBodyGyroMag
# - tBodyGyroJerkMag
# - fBodyAcc-XYZ
# - fBodyAccJerk-XYZ
# - fBodyGyro-XYZ
# - fBodyAccMag
# - fBodyAccJerkMag
# - fBodyGyroMag
# - fBodyGyroJerkMag
#
# The set of variables that were estimated from these signals are:
#
#  - mean(): Mean value
#  - std(): Standard deviation
#  - mad(): Median absolute deviation
#  - max(): Largest value in array
#  - min(): Smallest value in array
#  - sma(): Signal magnitude area
#  - energy(): Energy measure. Sum of the squares divided by the number of values.
#  - iqr(): Interquartile range
#  - entropy(): Signal entropy
#  - arCoeff(): Autorregresion coefficients with Burg order equal to 4
#  - correlation(): correlation coefficient between two signals
#  - maxInds(): index of the frequency component with largest magnitude
#  - meanFreq(): Weighted average of the frequency components to obtain a mean frequency
#  - skewness(): skewness of the frequency domain signal
#  - kurtosis(): kurtosis of the frequency domain signal
#  - bandsEnergy(): Energy of a frequency interval within the 64 bins of the FFT of each window.
#  - angle(): Angle between to vectors.
#
# Additional vectors obtained by averaging the signals in a signal window sample. These are used on the angle() variable:
#
# - gravityMean
# - tBodyAccMean
# - tBodyAccJerkMean
# - tBodyGyroMean
# - tBodyGyroJerkMean
#
# The complete list of variables of each feature vector is available in 'features.txt' in my repository **Add link here**
#
#
# ![HAR.png](attachment:HAR.png)

# %% [markdown]
# **Data Characterictics :**
# - Data Rows - 10299
# - Data Columns - 561
#
# - [ Data Source](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones)
#
#
#
# **Attribute Information:**
#
# For each record in the dataset it is provided:
# - Triaxial acceleration from the accelerometer (total acceleration) and the estimated body acceleration.
# - Triaxial Angular velocity from the gyroscope.
# - A 561-feature vector with time and frequency domain variables.
# - Its activity label.
# - An identifier of the subject who carried out the experiment.

# %% [markdown]
# ## Problem Statement
# In today's world, many people die as a result of disease outbreaks and bad lifestyles. People have become more conscious of their lifestyle choices and are attempting to improve their fitness. As a result, any digital companion that supports human fitness, such as recording calories burned, sleep cycle, and other records, is an added benefit. As an athlete, I believe it is critical to keep track of all of these factors in order to live a healthy lifestyle.

# %% [markdown]
# ## Motivation
# When I was 21, I got my first Fitbit watch, and I was constantly curious about the amazing function that had been released. Activity tracking was one of the features. When the same feature was released in Apple and later Android devices, I was perplexed. This kept me on my toes, and I learned that the data came from the sensors, but I had no idea what types of sensors there were or what the underlying mechanism was. I was taught all of the necessary topics to develop the same underlying technology that I fantasized about throughout my late childhood thanks to Prof. Christopher McGraw's course.

# %% [markdown]
# ## Objectives

# %% [markdown]
# - To classify multinomial variables with 6 degrees of freedom using classification models.
# - Models using dimension reduction approaches
# - Aim for a high accuracy score

# %% [markdown]
# ## Data Ingestion

# %%
 #Importing necessary libraries
import pandas as pd
import numpy as np


# Importing visualisation libraries

import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
pwd #Checking current working directory
# Out:
# 'C:\\Users\\Sushruth\\Downloads'

# %%
# Let's get the features from file features.txt

features = []
with open("UCI_HAR_Dataset/features.txt") as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
print("No. of unique features:{}".format(len(set(features))))
# Out:
# No of Features: 561
# No. of unique features:477

# %% [markdown]
# ###  Consolidating Train Data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_Dataset//train//X_train//X_train.txt', delim_whitespace=True, header=None)
X_train.columns = [features]
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_Dataset//train//subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_Dataset//train//y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1:'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['Activity_Name'] = y_train_labels
train.sample(10)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 3857          0.276870         -0.015065         -0.110244        -0.992342
# 2231          0.270624         -0.022044         -0.127398        -0.996585
# 44            0.278599         -0.019910         -0.111181        -0.994745
# 6658          0.277602         -0.010131         -0.102416        -0.990505
# 663           0.121385         -0.100539         -0.178158        -0.302313
# 5814          0.246288         -0.023888         -0.098246        -0.425519
# 3101          0.280204         -0.019931         -0.108829        -0.995587
# 4386          0.276363         -0.020289         -0.113701        -0.995733
# 2976          0.312031         -0.037260         -0.125744        -0.402102
# 3613          0.280212         -0.009867         -0.107093        -0.998098
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# ...

# %% [markdown]
# ### Consolidating Test Data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_Dataset//test//X_test//X_test.txt', delim_whitespace=True, header=None)
X_test.columns = [features]
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_Dataset//test//subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_Dataset//test//y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1:'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample(10)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 1326          0.161757         -0.017864         -0.055974        -0.081521
# 2422          0.304276          0.008339         -0.116871        -0.978421
# 2872          0.282065         -0.001213         -0.107890        -0.414021
# 607           0.230884         -0.025105         -0.070413        -0.220075
# 2362          0.422095          0.019165         -0.086064        -0.041764
# 973           0.281462         -0.009643         -0.107072        -0.997435
# 2266          0.278089         -0.017324         -0.105207        -0.996713
# 2634          0.264797         -0.016721         -0.102449        -0.981165
# 375           0.273222         -0.018568         -0.107051        -0.983165
# 1474          0.334239         -0.035852         -0.078448         0.004746
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# ...

# %%
#Shape of Train and Test Data
print('Train shape - ', train.shape)
print('Test shape - ', test.shape)
# Out:
# Train shape -  (7352, 564)
# Test shape -  (2947, 564)

# %%
train.columns #This is MultiIndex, Need to change this to tring and change the column values
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %% [markdown]
# ###  Consolidating both Test and Train Data
# For EDA purpose

# %%
#Exporting the Data frames
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# %% [markdown]
# Reason - I was getting Error during EDA - *'The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().'*
#
# Also Using a MultiIndex would be a problem.
#
# Hence, Exporting and importing the data will solve the Issue

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %%
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
# ...

# %%
# Appeding Data from Train to Test
HAR_Data = test.append(train, ignore_index = True)
print(HAR_Data.shape)
HAR_Data.head()
# Out:
# (10299, 564)
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
# ...

# %%
HAR_Data.to_csv('HAR_Data.csv')

# %% [markdown]
# ###  Data Ingestion Observations
# - There were serparate files of train and test data in 73%:27% ratio as X,Y split attibutes.
# - I merged the both to save time and lines of code
# - Feature set was a different file, I had to map it onto main data file

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ###  Checking Dataframe Properties

# %%
HAR_Data.info() # Data Type check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 564 entries, tBodyAccmeanX to Activity_Name
# dtypes: float64(561), int64(2), object(1)
# memory usage: 44.3+ MB

# %%
HAR_Data.describe() # Data Type check
# Out:
#        tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  \
# count   10299.000000   10299.000000   10299.000000  10299.000000
# mean        0.274347      -0.017743      -0.108925     -0.607784
# std         0.067628       0.037128       0.053033      0.438694
# min        -1.000000      -1.000000      -1.000000     -1.000000
# 25%         0.262625      -0.024902      -0.121019     -0.992360
# 50%         0.277174      -0.017162      -0.108596     -0.943030
# 75%         0.288354      -0.010625      -0.097589     -0.250293
# max         1.000000       1.000000       1.000000      1.000000
#
#        tBodyAccstdY  tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  \
# count  10299.000000  10299.000000  10299.000000  10299.000000  10299.000000
# mean      -0.510191     -0.613064     -0.633593     -0.525697     -0.614989
# std        0.500240      0.403657      0.413333      0.484201      0.399034
# ...

# %%
HAR_Data.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %% [markdown]
# ###  Checking for redundant rows

# %%
print('Duplicates for data - ',HAR_Data.duplicated().sum()) #to find duplicate rows
# Out:
# Duplicates for data -  0

# %% [markdown]
# ###  Checking for Null Values

# %%
print('Number of Nans/Null data - ' ,HAR_Data.isnull().sum())
# Out:
# Number of Nans/Null data -  tBodyAccmeanX        0
# tBodyAccmeanY        0
# tBodyAccmeanZ        0
# tBodyAccstdX         0
# tBodyAccstdY         0
#                     ..
# angleYgravityMean    0
# angleZgravityMean    0
# subject              0
# Activity             0
# Activity_Name        0
# Length: 564, dtype: int64

# %% [markdown]
# ##  Data Exploration

# %%
HAR_Data = pd.read_csv('HAR_Data.csv', encoding='utf-8', index_col=0)
print(HAR_Data.shape)

HAR_Data.head()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x="subject",hue="Activity_Name", data = HAR_Data)
plt.show()

# %% [markdown]
# Observation -
# - Subject '21' has provided most data wrt to Standing/Sitting/Laying. (probably works a Desk Job)
# - Subject '1' Walked a lot! ( Walks to work ? )
# - Subject '25','30' Climbed stairs the most ( were on a diet ? )

# %%
# Let's check number of observations per label
plt.figure(figsize=(12,5))
sns.countplot(HAR_Data.Activity_Name)
plt.title('Number of Observations/Activity', fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation -
# - Standing and sitting data were recorded the most
# - Data is balanced

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity_Name', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.title('tBodyAccMagmean parameter based on Activity', fontsize=20)

plt.show()

# %% [markdown]
# Observation -
# - The Left gaussian peaks shows **stationary Activities** , where the Body  accelerometer value is more; Vice Versa.
# - The Right Gaussian peaks shows **Non-Statinary Activities**, here the Body  accelerometer value is less and Vice Versa.

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity_Name', height=5,aspect=2)
facetgrid.map(sns.distplot,'angletBodyAccMeangravity', hist=False)\
    .add_legend()

# %% [markdown]
# Oberservation -
# - High peaks of gaussian curve is of Stationary activities of Body gravity acceleration values
# - Low Peaks are of Non-Stationary Actvity of Body gravity acceleration values.

# %%
plt.figure(figsize=(10,5))
plt.title('Subject Wise Data Distribution')
sns.countplot(x='subject' , data=HAR_Data )
plt.show()

# %% [markdown]
# Obeservation -
# -  Subject 21 has provided more data enties and Subject 2(lazy Guy) has logged less data entries

# %%
#Magnitude of an acceleration can saperate it well¶
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity_Name', y='tBodyAccMagmean',data=HAR_Data, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observations:
#
# - Standing, Sitting, or Laying are the Activities if tAccMean is -0.8.
# - Walking, WalkingDownstairs, or WalkingUpstairs are the Activities if tAccMean is > -0.6.
# - The Activity WalkingDownstairs is defined as tAccMean > 0.0.

# %%
# Position of GravityAccelerationComponants also matters¶
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity_Name', y='angleXgravityMean', data=HAR_Data)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# Observation -
# - Activity is Laying if angleX,gravityMean > 0.

# %%
sns.boxplot(x='Activity_Name', y='angleYgravityMean', data = HAR_Data, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.figure(figsize=(7,7))
plt.show()

# %%
pd.plotting.andrews_curves(HAR_Data, 'Activity_Name',color=['r','g','b','c','m','y'])
plt.show()

# %% [markdown]
# visualizing multidimensional data by mapping each observation

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
dfPca = pd.DataFrame(pca.fit_transform(HAR_Data.iloc[:, :2]), columns=['pc1','pc2'])
dfM = train.join(dfPca)
dfM.head()
sns.relplot(x='pc1', y='pc2', hue='Activity_Name', data=dfM)
plt.title('Activity Distribution in 2D ')

plt.show()

# %% [markdown]
# Obeservation -
# - Activity paramters cannot be be distinguished and are evenly spread out

# %%
g = sns.FacetGrid(dfM, col="Activity_Name", hue='Activity_Name')
plt.figure(figsize=(9,9))
g.map(sns.scatterplot, "pc1", "pc2", alpha=.9)
plt.title('Closer lookon Activity Distribution in 2D')

plt.show()

# %% [markdown]
# This confirms that they are pretty much bundled similar after taking the PCA values

# %%
yrAvg = HAR_Data.groupby('Activity_Name')['tBodyAccmeanX'].mean()
yrErr = HAR_Data.groupby('Activity_Name')['tBodyAccmeanX'].std()

fig, ax = plt.subplots()
yrAvg.plot.bar(yerr=yrErr, ax=ax, capsize=4, rot=0)
plt.title('Mean Body acceleration as per Activity')
plt.xlabel('')
plt.show()

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Importing Libraries

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

from sklearn.decomposition import PCA

# %%
HAR_Data.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'Activity_Name'],
#       dtype='object', length=564)

# %%
X = pd.DataFrame(HAR_Data.drop(['Activity_Name','Activity','subject'],axis=1))
y = HAR_Data.Activity_Name.values.astype(object)

# %%
X.shape, y.shape
# Out:
# ((10299, 561), (10299,))

# %% [markdown]
# ### Creating Pipeline

# %%
# Creating list for Numerical Columns
num_vars = HAR_Data.select_dtypes(include=np.number).columns.tolist()
num_vars
print(type(num_vars))
print(len(num_vars))
# Out:
# <class 'list'>
# 563

# %%
# Creating list for Categorical Columns
cat_vars = HAR_Data.select_dtypes(include=np.object).columns.tolist()
cat_vars
print(type(cat_vars))
print(len(cat_vars))
# Out:
# <class 'list'>
# 1

# %%
#Creating Pipeline
# 1. There are no missing data, but its no harm to add
#2. Scaling data using StandardScaler for numerical data
#3. Encoding data using OneHotEncoder for Categorical Variables


num_pipeline = Pipeline([('impute_missing', SimpleImputer(strategy='median')),
                           ('standardize_num', StandardScaler())
                        ])

cat_pipeline = Pipeline([('impute_missing_cats', SimpleImputer(strategy='most_frequent')),
                         ('create_dummies_cats', OneHotEncoder(handle_unknown='ignore', drop='first'))])

processing_pipeline = ColumnTransformer(transformers=[('proc_numeric', num_pipeline, num_vars)
                                                      ,
                                                      ('create_dummies', cat_pipeline, cat_vars)
                                                     ])

print(processing_pipeline)
# Out:
# ColumnTransformer(transformers=[('proc_numeric',
#                                  Pipeline(steps=[('impute_missing',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardize_num',
#                                                   StandardScaler())]),
#                                  ['tBodyAccmeanX', 'tBodyAccmeanY',
#                                   'tBodyAccmeanZ', 'tBodyAccstdX',
#                                   'tBodyAccstdY', 'tBodyAccstdZ',
#                                   'tBodyAccmadX', 'tBodyAccmadY',
#                                   'tBodyAccmadZ', 'tBodyAccmaxX',
#                                   'tBodyAccmaxY', 'tBodyAccmaxZ',
#                                   'tBodyAccmi...
#                                   'tBodyAccentropyX', 'tBodyAccentropyY',
#                                   'tBodyAccentropyZ', 'tBodyAccarCoeffX1',
# ...

# %% [markdown]
# ###  Splitting Data

# %%
#Splittng data to 30:70 as there are more columns to consider,
#I would need more data to train the model and ensure It wont overfit 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 99)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7209, 561), (3090, 561), (7209,), (3090,))

# %% [markdown]
# ###  Modelling : Logistic Regression using PCA

# %% [markdown]
# - Using Gridsearch to get optimal value of
#  - PCA components
#  - LogC value
# - Cross Validation is set to min 2
# - Refit is True to optimise the results

# %%
lg_pipe = modeling_pipeline = Pipeline([
        ('scaler', StandardScaler()),
         ('pca', PCA(n_components=5)),
         ('logreg', LogisticRegression(penalty='l2', solver='liblinear', max_iter = 700))
        ]
    )

from sklearn.model_selection import GridSearchCV
param_grid = [
  {'logreg__C': [400,500,700,900], 'pca__n_components': [50,80,100,500]}
 ]

lg_results = GridSearchCV(estimator=lg_pipe, param_grid=param_grid, scoring='accuracy', cv=2, refit = True)
lg_results = lg_results.fit(X_train, y_train)
lg_results.best_estimator_ #Using Best Estimator to get the optimal parameters
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=500)),
#                 ('logreg',
#                  LogisticRegression(C=400, max_iter=700, solver='liblinear'))])

# %%
print('---------------------------------------')
print(f'Validation score: {lg_results.best_score_:.2%}')
print(f'Test score: {lg_results.score(X_test, y_test):.2%}')
print('---------------------------------------')
# Out:
# ---------------------------------------
# Validation score: 97.60%
# Test score: 97.96%
# ---------------------------------------

# %%
y_testp = lg_results.predict(X_test)
y_testp_lgp = lg_results.predict_proba(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_testp))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       575
#            SITTING       0.93      0.95      0.94       523
#           STANDING       0.95      0.95      0.95       567
#            WALKING       1.00      1.00      1.00       528
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       428
#   WALKING_UPSTAIRS       1.00      1.00      1.00       469
#
#           accuracy                           0.98      3090
#          macro avg       0.98      0.98      0.98      3090
#       weighted avg       0.98      0.98      0.98      3090

# %%
from sklearn.metrics import roc_auc_score
lg_roc = roc_auc_score(y, lg_results.predict_proba(X), multi_class='ovr',average='weighted')
lg_roc
# Out:
# 0.9996645726790869

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(lg_results, X_test, y_test)
plt.show()

# %% [markdown]
# ### Modelling : Logistic Regression using Kernal PCA

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import KernelPCA

lg_pipe = modeling_pipeline = Pipeline([
        ('scaler', StandardScaler()),
         ('kpca', KernelPCA()),
         ('logreg', LogisticRegression(penalty='l2', solver='liblinear', max_iter = 600))
        ]
    )

from sklearn.model_selection import GridSearchCV
param_grid = [
  {'logreg__C': [400,500,600], 'kpca__n_components': [40,50,60],'kpca__kernel': ['poly', 'rbf']}
 ]

gcv_results = GridSearchCV(estimator=lg_pipe, param_grid=param_grid, scoring='accuracy', refit = True)
gcv_results = gcv_results.fit(X_train, y_train)
gcv_results.best_estimator_ #Using Best Estimator to get the optimal parameters

# %%
print('---------------------------------------')
print(f'Validation score: {gcv_results.best_score_:.2%}')
print(f'Test score: {gcv_results.score(X_test, y_test):.2%}')
print('---------------------------------------')

# %%
y_test_KPCAp = gcv_results.predict(X_test)
y_testp__KPCAlgp = gcv_results.predict_proba(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_KPCAp))

# %%
from sklearn.metrics import roc_auc_score
GCV_roc = roc_auc_score(y, gcv_results.predict_proba(X), multi_class='ovr',average='weighted')
GCV_roc

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(gcv_results, X_test, y_test)
plt.show()

# %% [markdown]
# ###  Modelling : Decision Tree

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

lg_pipe = modeling_pipeline = Pipeline([
        ('scaler', StandardScaler()),
         ('dt', DecisionTreeClassifier())
        ]
    )

from sklearn.model_selection import GridSearchCV
param_grid = [
  {'dt__max_depth': [3,4,5,6,7,8],
   'dt__min_samples_split': [2,4,6,8] 
  }
 ]

DC_results = GridSearchCV(estimator=lg_pipe, param_grid=param_grid, scoring='accuracy', refit = True)
DC_results = DC_results.fit(X_train, y_train)
DC_results.best_params_
# Out:
# {'dt__max_depth': 8, 'dt__min_samples_split': 2}

# %%
print('---------------------------------------')
print(f'Validation score: {DC_results.best_score_:.2%}')
print(f'Test score: {DC_results.score(X_test, y_test):.2%}')
print('---------------------------------------')
# Out:
# ---------------------------------------
# Validation score: 92.44%
# Test score: 94.43%
# ---------------------------------------

# %%
y_testDTp = lg_results.predict(X_test)
y_testp_DTp = lg_results.predict_proba(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_testDTp))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       575
#            SITTING       0.93      0.95      0.94       523
#           STANDING       0.95      0.95      0.95       567
#            WALKING       1.00      1.00      1.00       528
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       428
#   WALKING_UPSTAIRS       1.00      1.00      1.00       469
#
#           accuracy                           0.98      3090
#          macro avg       0.98      0.98      0.98      3090
#       weighted avg       0.98      0.98      0.98      3090

# %%
from sklearn.metrics import roc_auc_score
dt_roc = roc_auc_score(y, DC_results.predict_proba(X), multi_class='ovr',average='weighted')
dt_roc
# Out:
# 0.9929612882465481

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(lg_results, X_test, y_test)
plt.show()

# %%
featureNames = HAR_Data.columns

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model = DecisionTreeClassifier(criterion='gini', random_state=1, max_depth=8, min_samples_split=6)
tree_model.fit(X_train, y_train)

from sklearn import tree

plt.figure(figsize=(10,10))
tree.plot_tree(tree_model, feature_names=featureNames, fontsize=10)
plt.show()

# %% [markdown]
# ### Modelling : SVM Tree

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay

svm_m = modeling_pipeline = Pipeline([('scaling', StandardScaler()),
                                       ('model', SVC())])


param_grid = [
  {'model__C': [ 1, 10, 100], 'model__kernel': ['linear','rbf']}
 ]

svm_results = GridSearchCV(estimator=svm_m, param_grid=param_grid, scoring='accuracy')
svm_results = svm_results.fit(X_train, y_train)
svm_results.best_estimator_
# Out:
# Pipeline(steps=[('scaling', StandardScaler()), ('model', SVC(C=100))])

# %%
print('---------------------------------------')
print(f'Validation score: {svm_results.best_score_:.2%}')
print(f'Test score: {svm_results.score(X_test, y_test):.2%}')
print('---------------------------------------')
# Out:
# ---------------------------------------
# Validation score: 98.60%
# Test score: 98.32%
# ---------------------------------------

# %%
y_testSVMp = lg_results.predict(X_test)
y_testp_SVMp = lg_results.predict_proba(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_testSVMp))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       575
#            SITTING       0.93      0.95      0.94       523
#           STANDING       0.95      0.95      0.95       567
#            WALKING       1.00      1.00      1.00       528
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       428
#   WALKING_UPSTAIRS       1.00      1.00      1.00       469
#
#           accuracy                           0.98      3090
#          macro avg       0.98      0.98      0.98      3090
#       weighted avg       0.98      0.98      0.98      3090

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(svm_results, X_test, y_test)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
dt_roc = roc_auc_score(y, DC_results.predict_proba(X), multi_class='ovr',average='weighted')
dt_roc
# Out:
# 0.9929612882465481

# %% [markdown]
# ###  Modelling :K Nearest Neighbours (KNN)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay

knn_m = modeling_pipeline = Pipeline([('scaling', StandardScaler()),
                                       ('model', KNeighborsClassifier())])


param_grid = [
  {'model__n_neighbors': [1, 4, 8, 10, 15], 'model__weights': ['uniform','distance']}
 ]

knn_results = GridSearchCV(estimator=knn_m, param_grid=param_grid, scoring='accuracy', refit=True, cv=5)
knn_results = knn_results.fit(X_train, y_train)

ConfusionMatrixDisplay.from_estimator(knn_results, X_test, y_test)
plt.show()

# %%
print('-------------------------')
print(f'Validation score: {knn_results.best_score_:.2%}')
print(f'Test score: {knn_results.score(X_test, y_test):.2%}')
print('-------------------------')

y_test_Ran = knn_results.predict(X_test)
y_test_Ran_p = knn_results.predict_proba(X_test)
# Out:
# -------------------------
# Validation score: 96.02%
# Test score: 97.31%
# -------------------------

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_Ran))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.99      0.99      0.99       575
#            SITTING       0.95      0.92      0.93       523
#           STANDING       0.93      0.96      0.95       567
#            WALKING       0.99      0.99      0.99       528
# WALKING_DOWNSTAIRS       0.99      0.99      0.99       428
#   WALKING_UPSTAIRS       0.99      1.00      0.99       469
#
#           accuracy                           0.97      3090
#          macro avg       0.97      0.97      0.97      3090
#       weighted avg       0.97      0.97      0.97      3090

# %%
from sklearn.metrics import roc_auc_score
knn_roc = roc_auc_score(y, knn_results.predict_proba(X), multi_class='ovr',average='weighted')
knn_roc
# Out:
# 0.9992534593365499

# %% [markdown]
#  ## Feature Importance with Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier
rnd_clf = RandomForestClassifier(n_estimators=500)
rnd_clf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

imps = list(zip(features, rnd_clf.feature_importances_))

fi = pd.Series([x[1] for x in imps], index=[x[0] for x in imps])
fi = fi.sort_values(ascending=True)

fi.sort_values(ascending = False).nlargest(n=15).plot.barh()
plt.title('Feature Importances', loc='left')
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = {'base_estimator__max_depth': [1,2],
         'n_estimators': [100, 200, 400]
         }
ada_class = AdaBoostClassifier(DecisionTreeClassifier())
ada_gs = GridSearchCV(ada_class, param_grid = ada, cv=3, scoring='accuracy')
ada_gs = ada_gs.fit(X_train, y_train)
ada_pred = ada_gs.predict(X_test)

# %%
print(f'AdaBoost Validation Score: {ada_gs.best_score_:.2%}')
print(f'AdaBoost Test score : {ada_gs.score(X_test, y_test):.2%}')

# %% [markdown]
# ## Results

# %%
lg_score = lg_results.score(X_test, y_test)
#gcv_score = gcv_results.score(X_test, y_test)
DC_score = DC_results.score(X_test, y_test)
svm_score = svm_results.score(X_test, y_test)
knn_score = knn_results.score(X_test, y_test)

print(f'Logistic Regression Score using PCA: {lg_score:.2%}')
#print(f'Logistic Regression Score using Kernal PCA: {gcv_score:.2%}')
print(f'Decision Tree Score: {DC_score:.2%}')
print(f'Support Vector Machine Score: {svm_score:.2%}')
print(f'k-Nearest Neighbor Score: {knn_score:.2%}')
# Out:
# Logistic Regression Score using PCA: 97.96%
# Decision Tree Score: 94.43%
# Support Vector Machine Score: 98.32%
# k-Nearest Neighbor Score: 97.31%

# %%
#pip install jupyter_contrib_nbextensions

# %%
#!jupyter contrib nbextension install --user

# %%
#!jupyter nbextension enable codefolding/main

# %% [markdown]
# ## Challenges
# - I chose a dataset with an excessive number of rows because it was ambitious.
# - This was an advanced multinomial classification challenge, since I spent a significant amount of time overcoming issues such as
#  - Multicass format issues.
#  - Multi Index and uni-Index related Issues.
#  - Problems with Multiple-Label Indicators
#  - Value Errors, such as Not Enough Values to Unpack - Problems with Multiclass AUC Curves
# - Tuning the model to resolve overfitting proved tricky for me.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# - Use of gridsearch have improved the score by few pointers.
# - Since there are 500+ columns models are bit overfit, as the AUC score is around 97 to 99 . I could adopted below technique to prevent overfitting
#     - Cross validation techniques - kfolds
#     - Ensembling Techniques - Bagging,Boosting
